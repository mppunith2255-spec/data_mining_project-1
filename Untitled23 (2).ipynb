# %% [markdown]
# objective
#
# to build a convolutioal autoencoder(cae) that compresses facial images into a lower-dimensional latent representaton
# and reconstructs them with minimal loss of information
#
# purpose
#
# a converactional autoencoder is an unsupervised deep learning model used for:
#
# image compression image reconstruction feature extraction dimensionality reduction
#
# the encoder learn a compressed  represenatation (latent space ) while the decoder reconsructs the original image from the compressed represenalation

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("jessicali9530/celeba-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'celeba-dataset' dataset.
# Path to dataset files: /kaggle/input/celeba-dataset

# %%
import os
import shutil
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import UpSampling2D

# %%
#creste a smaller dataset (5000 images)
source_folder = os.path.join(path,"img_align_celeba","img_align_celeba")
destination_folder = "celeba_small/faces"
os.makedirs(destination_folder,exist_ok=True)
images = sorted(os.listdir(source_folder))[:5000]

for img in images:
    shutil.copy(
        os.path.join(source_folder,img),
        destination_folder
        )
print("copied",len(images),"images")
# Out:
# copied 5000 images

# %%
#data preprocessing
IMAGE_SIZE = (64,64)

barch_size = 32

# %%
datgen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

# %%
#load Dataset
train_generator = datgen.flow_from_directory(
    "celeba_small",
    target_size=IMAGE_SIZE,
    batch_size=barch_size,
    class_mode="input",
    subset="training"
)
# Out:
# Found 4000 images belonging to 1 classes.

# %%
validation_generator = datgen.flow_from_directory(
    "celeba_small",
    target_size=IMAGE_SIZE,
    batch_size=barch_size,
    class_mode="input",
    subset="validation"
)
# Out:
# Found 1000 images belonging to 1 classes.

# %%
images,_ = next(train_generator)
plt.figure(figsize=(10,5))
for i in range(5):
   plt.subplot(1,5,i+1)
   plt.imshow(images[i])
   plt.axis("off")
plt.show()

# %%
#encoder
input_img = Input(shape=(64,64,3))
x = Conv2D(
    32,
    (3,3),
    activation="relu",
    padding="same"
  )(input_img)
x= MaxPooling2D(
    (2,2),
    padding="same"
  )(x)
x=Conv2D(
    64,
    (3,3),
    activation="relu",
    padding="same"
  )(x)
encoded=MaxPooling2D(
    (2,2),
    padding="same"
  )(x)

# %%
from IPython.lib.security import encode
#decoder
x=Conv2D(
    64,
    (3,3),
    activation="relu",
    padding="same"
  )(encoded)
x=UpSampling2D((2,2))(x)
x=Conv2D(
    32,
    (3,3),
    activation="relu",
    padding="same"
  )(x)
x=UpSampling2D((2,2))(x)
decoded = Conv2D(
    3,
    (3,3),
    activation="sigmoid",
    padding="same"
  )(x)

# %%
#creat model
autoencoder = Model(
    input_img,
    decoded
  )

# %%
#comiple model
from tensorflow.keras.optimizers import Adam
op=Adam(learning_rate=0.2)
autoencoder.compile(optimizer=op,loss='mse')

# %%
#model summery
autoencoder.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 64, 64, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ...

# %%
#train model
history = autoencoder.fit(
    train_generator,
    epochs=20,
    validation_data=validation_generator
  )
# Out:
# Epoch 1/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - loss: 0.2777 - val_loss: 0.2795
# Epoch 2/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 0.2792 - val_loss: 0.2795
# Epoch 3/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - loss: 0.2792 - val_loss: 0.2795
# Epoch 4/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.2792 - val_loss: 0.2795
# Epoch 5/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 0.2792 - val_loss: 0.2795
# Epoch 6/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.2792 - val_loss: 0.2795
# Epoch 7/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.2792 - val_loss: 0.2795
# Epoch 8/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 0.2792 - val_loss: 0.2795
# Epoch 9/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 0.2792 - val_loss: 0.2795
# Epoch 10/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 0.2792 - val_loss: 0.2795
# Epoch 11/20
# ...

# %%
#plot loss
plt.figure(figsize=(8,5))
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("traing vs validation loss")
plt.legend(["training","validation"])
plt.show()

# %%
#evaluate model
loss = autoencoder.evaluate(validation_generator)
print("validation loss:",loss)

# %%
#reconstruct images
images,_ = next(validation_generator)
reconstructed_images = autoencoder.predict(images)

# %%
#display results
n=5
plt.figure(figsize=(15,6))
for i in range(n):
    plt.subplot(2,n,i+1)
    plt.imshow(images[i])
    plt.title("original")
    plt.axis("off")
    plt.subplot(2,n,i+1+n)
    plt.imshow(reconstructed_images[i])
    plt.title("reconstructed")
    plt.axis("off")
plt.show()
